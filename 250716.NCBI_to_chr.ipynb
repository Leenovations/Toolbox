# %%
nc_to_chr = {
    ">NC_000001": ">chr1",
    ">NC_000002": ">chr2",
    ">NC_000003": ">chr3",
    ">NC_000004": ">chr4",
    ">NC_000005": ">chr5",
    ">NC_000006": ">chr6",
    ">NC_000007": ">chr7",
    ">NC_000008": ">chr8",
    ">NC_000009": ">chr9",
    ">NC_000010": ">chr10",
    ">NC_000011": ">chr11",
    ">NC_000012": ">chr12",
    ">NC_000013": ">chr13",
    ">NC_000014": ">chr14",
    ">NC_000015": ">chr15",
    ">NC_000016": ">chr16",
    ">NC_000017": ">chr17",
    ">NC_000018": ">chr18",
    ">NC_000019": ">chr19",
    ">NC_000020": ">chr20",
    ">NC_000021": ">chr21",
    ">NC_000022": ">chr22",
    ">NC_000023": ">chrX",
    ">NC_000024": ">chrY",
    ">NC_012920": ">chrM"}

nc_to_chr_gtf = {
    "NC_000001": "chr1",
    "NC_000002": "chr2",
    "NC_000003": "chr3",
    "NC_000004": "chr4",
    "NC_000005": "chr5",
    "NC_000006": "chr6",
    "NC_000007": "chr7",
    "NC_000008": "chr8",
    "NC_000009": "chr9",
    "NC_000010": "chr10",
    "NC_000011": "chr11",
    "NC_000012": "chr12",
    "NC_000013": "chr13",
    "NC_000014": "chr14",
    "NC_000015": "chr15",
    "NC_000016": "chr16",
    "NC_000017": "chr17",
    "NC_000018": "chr18",
    "NC_000019": "chr19",
    "NC_000020": "chr20",
    "NC_000021": "chr21",
    "NC_000022": "chr22",
    "NC_000023": "chrX",
    "NC_000024": "chrY",
    "NC_012920": "chrM"}

# DICT_SEQ = {}
# with open('/media/src/DB/hg38/GCF_000001405.40_GRCh38.p14_genomic.fa', 'r') as fa:
#     for line in fa:
#         line = line.strip()
#         if line.startswith('>'):
#             Chr = line.split(' ')[0]
#             DICT_SEQ[Chr] = []

# Order = -1
# with open('/media/src/DB/hg38/GCF_000001405.40_GRCh38.p14_genomic.fa', 'r') as fa:
#     for line in fa:
#         line = line.strip()
#         if line.startswith('>'):
#             Order += 1
#         else:
#             DICT_SEQ[list(DICT_SEQ.keys())[Order]].append(line)

# with open('/media/src/DB/hg38/NCBI.hg38.p14.fa', 'w') as note00:
#     for Chr in DICT_SEQ.keys():
#         if Chr.startswith('>NC'):
#             NEW_Chr = nc_to_chr[Chr.split('.')[0]]
#             note00.write(NEW_Chr + '\n')
#             note00.write('\n'.join(DICT_SEQ[Chr]) + '\n')

with open('/media/src/DB/hg38/GCF_000001405.40_GRCh38.p14_genomic.gtf', 'r') as gtf:
    with open('/media/src/DB/hg38/NCBI.hg38.p14.gtf', 'w') as note00:
        for line in gtf:
            line = line.strip()
            if line.startswith('#'):
                continue
            else:
                splitted = line.split('\t')
                if splitted[0].startswith('NC'):
                    Chr = [nc_to_chr_gtf[splitted[0].split('.')[0]]]
                    Rest = splitted[1:]
                    New_line = '\t'.join(Chr + Rest)
                    note00.write(New_line + '\n')
